# %% [markdown]
# # LambdaMART Training and Evaluation
# Train the production-style ranking model used by the application.

# %%
from src.train import train
train()

# %%
from src.evaluate import evaluate
evaluate()

# %% [markdown]
# The evaluation script prints NDCG@1, NDCG@3, NDCG@5 and NDCG@10. Use the measured values in the final project report.
